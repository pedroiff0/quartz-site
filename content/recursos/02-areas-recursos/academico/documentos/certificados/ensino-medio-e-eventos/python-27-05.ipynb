# %% [markdown]
# Produto  |Preço(R$) | Validade|
# :--------|:--------:|---------|
# Produto 1|10,00     |29/05    |
# Produto 2|9,89      | 02/06   |
# Produto 3|24,49     | 12/03   |
# Produto 4|2,50      | 01/01   |
#
# $$
# \sum_{n=1}^{\infty}\frac{2^{n}}{n!}=
# \lim_\frac{2^{n+1}}{(n+1)!}\cdot \frac{n!}{2^{n}}
# $$

# %% [markdown]
# Exercício 1: Faça a equação abaixo em
# markdown e o implemente em python.
#
# $$
# c= \frac{a^{2}+b^{2}}{(a+b)^{2}}
# $$
#
# *Receba os valores pelo usuário, e imprima o
# resultado.

# %%
a = float(input("Digite um numero:"))
quad = 2
b = float(input("Digite outro numero:"))

conta = (a**quad + b**quad)/(a+b)**quad

print("Resultado:", conta)
# Out:
# Digite um numero:2
# Digite outro numero:2
# Resultado: 0.5

# %% [markdown]
# Exercício 2: Faça um programa para o cálculo de uma folha de pagamento, sabendo que os descontos são do Imposto de Renda, que
# depende do salário bruto e 10% para o INSS. O Salário Líquido
# corresponde ao Salário Bruto menos os descontos. O programa deverá
# pedir ao usuário o valor da sua hora e a quantidade de horas
# trabalhadas no mês.
#
# Desconto do IR:
#
# Salário Bruto até 900 (inclusive) - isento;
#
# Salário Bruto até 1500 (inclusive) - desconto de 5%;
#
# Salário Bruto até 2500 (inclusive) - desconto de 10%;
#
# Salário Bruto acima de 2500 - desconto de 20%.

# %%
horas = float(input("Qual valor da sua hora (R$): "))
horas_mes = float(input("Quantas horas trabalhou no mês? "))

calculo = horas * horas_mes
reajuste = 0
inss = 0.1

if calculo <=900 : 
  print("Isento")

elif calculo > 901 and calculo <= 1500:  
  reajuste = (calculo * (5/100) - inss)
  print("Desconto de 5%, Valor descontado: ", reajuste)
  calculo = calculo - reajuste - inss 
  print("Salário com o reajuste: ", calculo)

elif calculo > 1501 and calculo <= 2500:  
  reajuste = calculo * (10/100)
  print("Desconto de 10%, Valor descontado: ", reajuste)
  calculo = calculo - reajuste - inss 
  print("Salário com o reajuste: ", calculo)

else:
  reajuste = calculo * (20/100)
  print("Desconto de 20%, Valor descontado: ", reajuste)
  calculo = calculo - reajuste - inss   
  print("Salário com o reajuste: ", calculo)

# %% [markdown]
# Exercício 3: Defina uma senha em uma variável qualquer, e
# solicite o usuário para adivinhar a senha. Faça isso enquanto o
# usuário não acertar.

# %%
senha = input("Defina uma senha: ")
(type(senha))
tentativa = True

while tentativa == True:
  senha2 = input("Advinhe a senha: ")
  if senha == senha2:
    print("Você acertou!!")
    tentativa = False
  else:
    print("Tente novamente!")
    tentiva = False
# Out:
# Defina uma senha: senha
# Advinhe a senha: false
# Tente novamente!
# Advinhe a senha: senha
# Você acertou!!

# %% [markdown]
# Exercício 4: Armazene os nomes e as notas de 5 alunos em listas,
# e imprima:
# 1. Os alunos que ficaram como nota abaixo de 6;
# 2. O aluno com a maior nota;
# 3. A média de todas as notas.

# %%
alunos = ["Pedro", "Miguel", "Matheus", "Taty", "Joana"]
notas = [6, 10, 9, 8, 10]

media = 0
for i in range(len(notas)):
 media = media + notas[i]
  media = media/len(notas)
    print(media)
# Out:
# 8.6
